# %%
quantity = 6
item = "bananas"
price = 1.74
f"{quantity} {item} cost {price * quantity: .2f}"
# Out:
# '6 bananas cost  10.44'

# %%
print(f"{item} é bom")
print(f"{item:<10} é bom")
print(f"{item:>10} é bom")
# Out:
# bananas é bom
# bananas    é bom
#    bananas é bom
